# %%
products = {
    101 : {"Name":"Parle-G Original",        "price":10,  "quan":100,  "expiry":"Jun 2024",  "brand":"Parle"},
    102 : {"Name":"Good-Day",                "price":30,  "quan":10,   "expiry":"Jul 2022",  "brand":"Britannia"},
    103 : {"Name":"Dark Fantasy Choco Fills","price":30,  "quan":100,  "expiry":"Aug 2024",  "brand":"Sunfeast"},
    104 : {"Name":"Monaco",                  "price":60,  "quan":120,  "expiry":"Jul 2022",  "brand":"Priya Gold"},
    105 : {"Name":"Cashew Cookies",          "price":100, "quan":200,  "expiry":"May 2022",  "brand":"Patanjali"},
    106 : {"Name":"Digestive High Gram",     "price":35,  "quan":150,  "expiry":"May 2024",  "brand":"Cremica"},
    107 : {"Name":"Oreo-Vanilla",            "price":200, "quan":120,  "expiry":"May 2024",  "brand":"Cadbury Oreo"},
    108 : {"Name":"Digestive Wheat",         "price":40,  "quan":155,  "expiry":"Jan 2024",  "brand":"McVitie’s"},
    109 : {"Name":"Dil Khush",               "price":55,  "quan":230,  "expiry":"May 2024",  "brand":"Anmol"},
    110 : {"Name":"Choco-Nut Cookies",       "price":45,  "quan":50,   "expiry":"Jan 2022",  "brand":"Unibic"},
    111 : {"Name":"Nibbles",                 "price":55,  "quan":59,   "expiry":"Aug 2022",  "brand":"Dukes"},
    112 : {"Name":"20-20 Cookies",           "price":90,  "quan":90,   "expiry":"Feb 2022",  "brand":"Parle"},
    113 : {"Name":"Marie-Gold",              "price":60,  "quan":95,   "expiry":"Dec 2021",  "brand":"Britannia"},
    114 : {"Name":"Pista-Badam",             "price":110, "quan":95,   "expiry":"Jun 2022",  "brand":"Haldiram's"},
    115 : {"Name":"Almond Butter Cookies",   "price":160, "quan":100,  "expiry":"Jul 2022",  "brand":"Nature Valley"},
    116 : {"Name":"Pillsbury cookes cake",   "price":68,  "quan":200,  "expiry":"Dec 2021",  "brand":"Pillsbury"},
    117 : {"Name":"Bourbon",                 "price":50,  "quan":120,  "expiry":"Dec 2021",  "brand":"Britannia"},
    118 : {"Name":"Mom's Magic Cashew",      "price":80,  "quan":10,   "expiry":"Mar 2022",  "brand":"Sunfeast"},
    119 : {"Name":"Oreo-Orange",             "price":60,  "quan":75,   "expiry":"Feb 2022",  "brand":"Cadbury Oreo"},
    120 : {"Name":"Oreo-Chocolate",          "price":90,  "quan":50,   "expiry":"Jan 2022",  "brand":"Cadbury Oreo"},
    121 : {"Name":"Magix",                   "price":10,  "quan":10,   "expiry":"Dec 2011",  "brand":"Parle"},
    122 : {"Name":"Honey Oatmeal",           "price":30,  "quan":450,  "expiry":"Feb 2023",  "brand":"Unibic"},
    123 : {"Name":"Doodh",                   "price":25,  "quan":40,   "expiry":"Dec 2023",  "brand":"Patanjali"},
    124 : {"Name":"Hide and Seek",           "price":45,  "quan":40,   "expiry":"Jan 2024",  "brand":"Parle"},
    125 : {"Name":"Fruit and Nut",           "price":90,  "quan":30,   "expiry":"Jan 2023",  "brand":"Unibic"},
    126 : {"Name":"Nariyal",                 "price":40,  "quan":60,   "expiry":"Dec 2024",  "brand":"Patanjali"},
    127 : {"Name":"Milk Bilkis",             "price":55,  "quan":70,   "expiry":"Jun 2023",  "brand":"Britannia"},
    128 : {"Name":"Krackjack",               "price":65,  "quan":60,   "expiry":"Jul 2023",  "brand":"Parle"},
    129 : {"Name":"Nutri Choice",            "price":45,  "quan":40,   "expiry":"Nov 2023",  "brand":"Britannia"},
    130 : {"Name":"Nice Time",               "price":15,  "quan":50,   "expiry":"Oct 2023",  "brand":"Britannia"}
}

# %%
products
# Out:
# {101: {'Name': 'Parle-G Original',
#   'brand': 'Parle',
#   'expiry': 'Jun 2024',
#   'price': 10,
#   'quan': 100},
#  102: {'Name': 'Good-Day',
#   'brand': 'Britannia',
#   'expiry': 'Jul 2022',
#   'price': 30,
#   'quan': 10},
#  103: {'Name': 'Dark Fantasy Choco Fills',
#   'brand': 'Sunfeast',
#   'expiry': 'Aug 2024',
#   'price': 30,
#   'quan': 100},
#  104: {'Name': 'Monaco',
#   'brand': 'Priya Gold',
#   'expiry': 'Jul 2022',
#   'price': 60,
#   'quan': 120},
#  105: {'Name': 'Cashew Cookies',
#   'brand': 'Patanjali',
#   'expiry': 'May 2022',
#   'price': 100,
#   'quan': 200},
#  106: {'Name': 'Digestive High Gram',
#   'brand': 'Cremica',
#   'expiry': 'May 2024',
#   'price': 35,
#   'quan': 150},
#  107: {'Name': 'Oreo-Vanilla',
#   'brand': 'Cadbury Oreo',
#   'expiry': 'May 2024',
#   'price': 200,
#   'quan': 120},
#  108: {'Name': 'Digestive Wheat',
#   'brand': 'McVitie’s',
#   'expiry': 'Jan 2024',
#   'price': 40,
#   'quan': 155},
# ...

# %%
import json

# %%
js = json.dumps(products)

# %%
fd = open("products.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# Read Data From JSON

# %%
fd = open("products.json",'r')
r = fd.read()
fd.close()

# %%
products = json.loads(r)

# %%
products
# Out:
# {'101': {'Name': 'Parle-G Original',
#   'brand': 'Parle',
#   'expiry': 'Jun 2024',
#   'price': 10,
#   'quan': 100},
#  '102': {'Name': 'Good-Day',
#   'brand': 'Britannia',
#   'expiry': 'Jul 2022',
#   'price': 30,
#   'quan': 10},
#  '103': {'Name': 'Dark Fantasy Choco Fills',
#   'brand': 'Sunfeast',
#   'expiry': 'Aug 2024',
#   'price': 30,
#   'quan': 100},
#  '104': {'Name': 'Monaco',
#   'brand': 'Priya Gold',
#   'expiry': 'Jul 2022',
#   'price': 60,
#   'quan': 120},
#  '105': {'Name': 'Cashew Cookies',
#   'brand': 'Patanjali',
#   'expiry': 'May 2022',
#   'price': 100,
#   'quan': 200},
#  '106': {'Name': 'Digestive High Gram',
#   'brand': 'Cremica',
#   'expiry': 'May 2024',
#   'price': 35,
#   'quan': 150},
#  '107': {'Name': 'Oreo-Vanilla',
#   'brand': 'Cadbury Oreo',
#   'expiry': 'May 2024',
#   'price': 200,
#   'quan': 120},
#  '108': {'Name': 'Digestive Wheat',
#   'brand': 'McVitie’s',
#   'expiry': 'Jan 2024',
#   'price': 40,
#   'quan': 155},
# ...

# %% [markdown]
# Add new items

# %%
prod_id = input("Enter the Product ID: ")
name = input("Enter the Name of the Product: ")
price = int(input("Enter the price per Item: "))
quan = int(input("Enter The Quantity of the Product you want to add: "))
expiry = input("Enter the expiry date of the Product: ")
brand = input("Enter the Brand of the product: ")
# Out:
# Enter the Product ID: 131
# Enter the Name of the Product: Choco Fills
# Enter the price per Item: 130
# Enter The Quantity of the Product you want to add: 7
# Enter the expiry date of the Product: May 2023
# Enter the Brand of the product: Britannia

# %%
products[prod_id] = {"name":name,"price":price,"quan":quan,"expiry":expiry,"brand":brand}

# %%
js = json.dumps(products)

# %%
fd = open("products.json","w")
fd.write(js)
fd.close()

# %%
products
# Out:
# {'101': {'Name': 'Parle-G Original',
#   'brand': 'Parle',
#   'expiry': 'Jun 2024',
#   'price': 10,
#   'quan': 100},
#  '102': {'Name': 'Good-Day',
#   'brand': 'Britannia',
#   'expiry': 'Jul 2022',
#   'price': 30,
#   'quan': 10},
#  '103': {'Name': 'Dark Fantasy Choco Fills',
#   'brand': 'Sunfeast',
#   'expiry': 'Aug 2024',
#   'price': 30,
#   'quan': 100},
#  '104': {'Name': 'Monaco',
#   'brand': 'Priya Gold',
#   'expiry': 'Jul 2022',
#   'price': 60,
#   'quan': 120},
#  '105': {'Name': 'Cashew Cookies',
#   'brand': 'Patanjali',
#   'expiry': 'May 2022',
#   'price': 100,
#   'quan': 200},
#  '106': {'Name': 'Digestive High Gram',
#   'brand': 'Cremica',
#   'expiry': 'May 2024',
#   'price': 35,
#   'quan': 150},
#  '107': {'Name': 'Oreo-Vanilla',
#   'brand': 'Cadbury Oreo',
#   'expiry': 'May 2024',
#   'price': 200,
#   'quan': 120},
#  '108': {'Name': 'Digestive Wheat',
#   'brand': 'McVitie’s',
#   'expiry': 'Jan 2024',
#   'price': 40,
#   'quan': 155},
# ...
